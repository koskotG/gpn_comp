# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df_train = pd.read_csv('train_1.8.csv', header = 0 ,encoding = 'cp1251', parse_dates = ['Дата'])
df_test = pd.read_csv('test_1.9.csv', header = 0 ,encoding = 'cp1251', parse_dates = ['Дата'])

# %%
df_test.head()
# Out:
#                            Скважина       Дата  ГТМ    Метод Характер работы  \
# 0  002ff5b8a6dc271f58581e1b4fa2c5fc 2016-12-01  1.0      ФОН             НЕФ
# 1  008d0347e572a5d938a9c40c29e539fc 2013-10-01  NaN      NaN             NaN
# 2  00b40cb7bb8c9fd1ac26b4cc86f2b291 2018-02-01  NaN      NaN             NaN
# 3  01ba18d8b6d29875a18d4bca4eb201d7 2014-05-01  0.0  ЭЦН/ФОН             НЕФ
# 4  024ec6f6e3f9c5150ecf525bf8b7a6a3 2017-06-01  1.0      ФОН             НЕФ
#
#   Состояние  Время работы, ч  Время накопления  Попутный газ, м3  Закачка, м3  \
# 0    ОСВ ТГ              0.0               0.0               0.0          0.0
# 1       NaN              NaN               NaN               NaN          NaN
# 2       NaN              NaN               NaN               NaN          NaN
# 3      РАБ.            120.0               0.0            6929.0          0.0
# 4    ОСВ ТГ              0.0               0.0               0.0          0.0
#
#                 ...                Пластовое давление начальное  \
# 0               ...                                         NaN
# 1               ...                                       255.0
# 2               ...                                       277.0
# 3               ...                                         NaN
# 4               ...                                         NaN
#
#    Характеристический дебит жидкости  Время в работе  Время в накоплении  \
# 0                                NaN             NaN                 NaN
# 1                           0.000000             0.0                 0.0
# 2                         521.430143             0.0                 0.0
# 3                                NaN             NaN                 NaN
# 4                                NaN             NaN                 NaN
#
#   ГП - Забойное давление  ГП(ИДН) Дебит жидкости  \
# 0                    NaN                     NaN
# 1                    0.0                0.000000
# 2                   32.0              201.400991
# 3                    NaN                     NaN
# 4                    NaN                     NaN
#
#   ГП(ИДН) Дебит жидкости скорр-ый  ГП(ИДН) Прирост дефита нефти  \
# 0                             NaN                           NaN
# 1                        0.000000                      0.000000
# 2                      201.400991                     29.611419
# 3                             NaN                           NaN
# 4                             NaN                           NaN
#
#    ГП(ГРП) Дебит жидкости ГП(ГРП) Дебит жидкости скорр-ый
# 0                     NaN                             NaN
# 1                     0.0                             0.0
# 2                     0.0                             0.0
# 3                     NaN                             NaN
# 4                     NaN                             NaN
#
# [5 rows x 114 columns]

# %%
df_coord_train = pd.read_csv('coords_train_1.1.csv', header = 0,encoding = 'cp1251')
df_coord_test = pd.read_csv('coords_test_1.1.csv', header = 0,encoding = 'cp1251')

# %%
df_frac_train = pd.read_csv('frac_train_1.csv', header = 0,encoding = 'cp1251')
df_frac_test = pd.read_csv('frac_test_1.csv', header = 0,encoding = 'cp1251')

# %%
df_gdis_train = pd.read_csv('gdis_train1.2.csv', header = 0,encoding = 'cp1251')
df_gdis_test = pd.read_csv('gdis_test1.2.csv', header = 0,encoding = 'cp1251')

# %%
df_coord['x'] = df_coord['ПЛАСТ_X'].astype(dtype='int32')
df_coord['y'] = df_coord['ПЛАСТ_Y'].astype(dtype='int32')
df_coord['x'] = df_coord['x'] - df_coord['x'].mean()
df_coord['y'] = df_coord['y'] - df_coord['y'].mean()

# %%
df_coord['x_head'] = df_coord['УСТЬЕ_X'].astype(dtype='int32')
df_coord['y_head'] = df_coord['УСТЬЕ_Y'].astype(dtype='int32')
df_coord['x_head'] = df_coord['x_head'] - df_coord['x_head'].mean()
df_coord['x_head'] = df_coord['x_head'] - df_coord['x_head'].mean()

# %%
df_gdis_train.head()
# Out:
#                            Скважина  Давление пластовое     Тип испытания
# 0  0b0688c9273d26bdd4870035682648cf               240.0  среднее качество
# 1  0b0688c9273d26bdd4870035682648cf               130.0  среднее качество
# 2  046568c4bd1c6343c5f932ef6a21b112               340.0   низкое качество
# 3  3a36efb8cb6fe16ed8f67ab3f1c55254               165.0  среднее качество
# 4  0b0688c9273d26bdd4870035682648cf               163.0   низкое качество

# %%
# %matplotlib notebook
plt.figure(figsize=(10,10))
plt.scatter(df_coord_train.drop_duplicates('well_hash', 'first')['ПЛАСТ_X'], 
            df_coord_train.drop_duplicates('well_hash', 'first')['ПЛАСТ_Y'], color = 'g', label='train')
plt.scatter(df_coord_test.drop_duplicates('well_hash', 'first')['ПЛАСТ_X'], 
            df_coord_test.drop_duplicates('well_hash', 'first')['ПЛАСТ_Y'], color = 'r', label='test')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="720">

# %%
w_coord_train = df_coord_train['well_hash'].unique()
w_coord_test = df_coord_test['well_hash'].unique()
w_train = df_train['Скважина'].unique()
w_test = df_test['Скважина'].unique()
w_frac_train = df_frac_train['Скважина'].unique()
w_frac_test = df_frac_test['Скважина'].unique()
w_gdis_train = df_gdis_train['Скважина'].unique()
w_gdis_test = df_gdis_test['Скважина'].unique()

# %%
print('# of wells in train: ', len(w_train))
print('# of wells in coord train: ', len(w_coord_train))
print('# of wells intersect train and coord train: ', len(list(set(w_train) & set(w_coord_train))))
print('# of wells in frac train: ', len(w_frac_train))
print('# of wells in gdis train: ', len(w_gdis_train))
# Out:
# # of wells in train:  563
# # of wells in coord train:  234
# # of wells intersect train and coord train:  233
# # of wells in frac train:  490
# # of wells in gdis train:  388

# %%
print('# of wells in test: ', len(w_test))
print('# of wells in coord test: ', len(w_coord_test))
print('# of wells in frac test: ', len(w_frac_test))
print('# of wells in gdis test: ', len(w_gdis_test))
# Out:
# # of wells in test:  266
# # of wells in coord test:  137
# # of wells in frac test:  193
# # of wells in gdis test:  106
